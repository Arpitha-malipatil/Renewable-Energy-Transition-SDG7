# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler


file_path = "cleaned_energy_data (1).csv.crdownload"
df = pd.read_csv("cleaned_energy_data (1).csv.crdownload")

print("Initial Shape:", df.shape)
print(df.head())


df.columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
    .str.replace("(", "", regex=False)
    .str.replace(")", "", regex=False)
    .str.replace("%", "percent")
)


if "Time" in df.columns:
    df["Time"] = pd.to_numeric(df["Time"], errors="coerce")

# Convert numeric columns properly
numeric_cols = df.select_dtypes(include=["object"]).columns
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors="ignore")

print("\nAfter Formatting:")
print(df.dtypes)



df.fillna(method="ffill", inplace=True)

df.fillna(df.select_dtypes(include=np.number).mean(), inplace=True)

print("\nMissing Values After Handling:")
print(df.isnull().sum())




numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    lower = df[col].quantile(0.01)
    upper = df[col].quantile(0.99)
    df[col] = df[col].clip(lower, upper)

print("\nOutliers handled using 1%-99% capping.")



scaler = MinMaxScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

print("\nData Normalized Successfully.")
print(df.head())



output_path = "preprocessed_energy_data.csv"
df.to_csv(output_path, index=False)

print("\nPreprocessed file saved at:")
print(output_path)
# Out:
# Initial Shape: (933, 15)
#   Country Name Country Code  Time Time Code  \
# 0  Afghanistan          AFG  2005    YR2005
# 1  Afghanistan          AFG  2006    YR2006
# 2  Afghanistan          AFG  2007    YR2007
# 3  Afghanistan          AFG  2008    YR2008
# 4  Afghanistan          AFG  2009    YR2009
#
#    Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]  \
# 0                                              13.49
# 1                                              14.81
# 2                                              15.99
# 3                                              17.44
# 4                                              18.84
#
#    Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]  \
# 0                                          13.000000
# 1                                          12.543863
# 2                                          18.916223
# 3                                          32.500000
# 4                                          31.845157
#
#    Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]  \
# 0                                          23.000000
# 1                                          28.228613
# 2                                          33.748680
# 3                                          42.400000
# 4                                          44.854885
#
#    Access to electricity (% of urban population with access) [1.3_ACCESS.ELECTRICITY.URBAN]  \
# 0                                          74.000000
# 1                                          80.042892
# 2                                          81.800255
# 3                                          89.900000
# 4                                          85.354507
#
#    Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                           1.267647
# 1                                           1.408623
# 2                                           1.460938
# 3                                           2.147590
# 4                                           2.617060
#
#    Renewable electricity output (GWh) [4.1.2_REN.ELECTRICITY.OUTPUT]  \
# 0                                              671.0
# 1                                              646.0
# 2                                              684.0
# 3                                              541.0
# 4                                              775.0
#
#    Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                          74.061810
# 1                                          70.755750
# 2                                          72.000000
# 3                                          68.654822
# 4                                          87.176603
#
#    Renewable energy consumption (TJ) [3.1_RE.CONSUMPTION]  \
# 0                                           13245.71
# 1                                           14324.37
# 2                                           15270.50
# 3                                           15312.85
# 4                                           16854.19
#
#    Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                          40.859171
# 1                                          37.137249
# 2                                          33.862579
# 3                                          21.343708
# 4                                          17.813855
#
#    Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                              906.0
# 1                                              913.0
# 2                                              950.0
# 3                                              788.0
# 4                                              889.0
#
#    Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                        32417.96054
# 1                                        38571.43487
# 2                                        45095.50226
# 3                                        71744.09407
# 4                                        94612.81812
#
# After Formatting:
# Country_Name                                                                                            object
# Country_Code                                                                                            object
# Time                                                                                                     int64
# Time_Code                                                                                               object
# Access_to_Clean_Fuels_and_Technologies_for_cooking_percent_of_total_population_[2.1_ACCESS.CFT.TOT]    float64
# Access_to_electricity_percent_of_rural_population_with_access_[1.2_ACCESS.ELECTRICITY.RURAL]           float64
# Access_to_electricity_percent_of_total_population_[1.1_ACCESS.ELECTRICITY.TOT]                         float64
# Access_to_electricity_percent_of_urban_population_with_access_[1.3_ACCESS.ELECTRICITY.URBAN]           float64
# Energy_intensity_level_of_primary_energy_MJ/2011_USD_PPP_[6.1_PRIMARY.ENERGY.INTENSITY]                float64
# Renewable_electricity_output_GWh_[4.1.2_REN.ELECTRICITY.OUTPUT]                                        float64
# Renewable_electricity_share_of_total_electricity_output_percent_[4.1_SHARE.RE.IN.ELECTRICITY]          float64
# Renewable_energy_consumption_TJ_[3.1_RE.CONSUMPTION]                                                   float64
# Renewable_energy_share_of_TFEC_percent_[2.1_SHARE.TOTAL.RE.IN.TFEC]                                    float64
# Total_electricity_output_GWh_[4.1.1_TOTAL.ELECTRICITY.OUTPUT]                                          float64
# Total_final_energy_consumption_TFEC_TJ_[1.1_TOTAL.FINAL.ENERGY.CONSUM]                                 float64
# dtype: object
#
# Missing Values After Handling:
# Country_Name                                                                                           0
# Country_Code                                                                                           0
# Time                                                                                                   0
# Time_Code                                                                                              0
# Access_to_Clean_Fuels_and_Technologies_for_cooking_percent_of_total_population_[2.1_ACCESS.CFT.TOT]    0
# Access_to_electricity_percent_of_rural_population_with_access_[1.2_ACCESS.ELECTRICITY.RURAL]           0
# Access_to_electricity_percent_of_total_population_[1.1_ACCESS.ELECTRICITY.TOT]                         0
# Access_to_electricity_percent_of_urban_population_with_access_[1.3_ACCESS.ELECTRICITY.URBAN]           0
# Energy_intensity_level_of_primary_energy_MJ/2011_USD_PPP_[6.1_PRIMARY.ENERGY.INTENSITY]                0
# Renewable_electricity_output_GWh_[4.1.2_REN.ELECTRICITY.OUTPUT]                                        0
# Renewable_electricity_share_of_total_electricity_output_percent_[4.1_SHARE.RE.IN.ELECTRICITY]          0
# Renewable_energy_consumption_TJ_[3.1_RE.CONSUMPTION]                                                   0
# Renewable_energy_share_of_TFEC_percent_[2.1_SHARE.TOTAL.RE.IN.TFEC]                                    0
# Total_electricity_output_GWh_[4.1.1_TOTAL.ELECTRICITY.OUTPUT]                                          0
# Total_final_energy_consumption_TFEC_TJ_[1.1_TOTAL.FINAL.ENERGY.CONSUM]                                 0
# dtype: int64
#
# Outliers handled using 1%-99% capping.
#
# Data Normalized Successfully.
#   Country_Name Country_Code      Time Time_Code  \
# 0  Afghanistan          AFG  0.333333    YR2005
# 1  Afghanistan          AFG  0.400000    YR2006
# 2  Afghanistan          AFG  0.466667    YR2007
# 3  Afghanistan          AFG  0.533333    YR2008
# 4  Afghanistan          AFG  0.600000    YR2009
#
#    Access_to_Clean_Fuels_and_Technologies_for_cooking_percent_of_total_population_[2.1_ACCESS.CFT.TOT]  \
# 0                                           0.128889
# 1                                           0.142181
# 2                                           0.154063
# 3                                           0.168664
# 4                                           0.182761
#
#    Access_to_electricity_percent_of_rural_population_with_access_[1.2_ACCESS.ELECTRICITY.RURAL]  \
# 0                                           0.127228
# 1                                           0.122652
# 2                                           0.186579
# 3                                           0.322849
# 4                                           0.316280
#
#    Access_to_electricity_percent_of_total_population_[1.1_ACCESS.ELECTRICITY.TOT]  \
# 0                                           0.188110
# 1                                           0.243240
# 2                                           0.301444
# 3                                           0.392664
# 4                                           0.418548
#
#    Access_to_electricity_percent_of_urban_population_with_access_[1.3_ACCESS.ELECTRICITY.URBAN]  \
# 0                                           0.682992
# 1                                           0.756671
# 2                                           0.778097
# 3                                           0.876855
# 4                                           0.821433
#
#    Energy_intensity_level_of_primary_energy_MJ/2011_USD_PPP_[6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.021411
#
#    Renewable_electricity_output_GWh_[4.1.2_REN.ELECTRICITY.OUTPUT]  \
# 0                                           0.001456
# 1                                           0.001402
# 2                                           0.001484
# 3                                           0.001174
# 4                                           0.001682
#
#    Renewable_electricity_share_of_total_electricity_output_percent_[4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                           0.740649
# 1                                           0.707587
# 2                                           0.720030
# 3                                           0.686577
# 4                                           0.871802
#
#    Renewable_energy_consumption_TJ_[3.1_RE.CONSUMPTION]  \
# 0                                           0.001611
# 1                                           0.001742
# 2                                           0.001857
# 3                                           0.001862
# 4                                           0.002050
#
#    Renewable_energy_share_of_TFEC_percent_[2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                           0.423898
# 1                                           0.385285
# 2                                           0.351311
# 3                                           0.221433
# 4                                           0.184812
#
#    Total_electricity_output_GWh_[4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                           0.000312
# 1                                           0.000315
# 2                                           0.000328
# 3                                           0.000269
# 4                                           0.000306
#
#    Total_final_energy_consumption_TFEC_TJ_[1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                           0.000644
# 1                                           0.000772
# 2                                           0.000908
# 3                                           0.001462
# 4                                           0.001937
#
# Preprocessed file saved at:
# preprocessed_energy_data.csv
# C:\Users\Pavan\AppData\Local\Temp\ipykernel_15012\3390669608.py:36: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors="ignore")
# C:\Users\Pavan\AppData\Local\Temp\ipykernel_15012\3390669608.py:47: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
